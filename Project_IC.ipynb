# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("classification_data1_clss.csv")

df.head()
# Out:
#       id  social-security-number  house-number  age-group     workclass  \
# 0   8616             830617145.0        8732.0        2.0  self-emp-inc
# 1  21982             151595184.0        1894.0        3.0     local-gov
# 2  11191             303184281.0        9466.0        0.0       private
# 3  22229             369287837.0        8511.0        2.0       private
# 4  20732             420084973.0        1281.0        3.0       private
#
#      fnlwgt  education  education-num      marital-status         occupation  \
# 0  270079.0  bachelors           13.0  married-civ-spouse    exec-managerial
# 1  146325.0  doctorate           16.0  married-civ-spouse     prof-specialty
# 2  240767.0    hs-grad            9.0       never-married      other-service
# 3  118536.0    hs-grad            9.0            divorced  machine-op-inspct
# 4  160440.0  bachelors           13.0  married-civ-spouse              sales
#
#      relationship   race     sex  capitalgain  capitalloss  hoursperweek  \
# 0         husband  white    male          0.0          0.0           3.0
# 1         husband  white    male          0.0          2.0           2.0
# 2   not-in-family  white  female          0.0          0.0           1.0
# 3  other-relative  black    male          0.0          0.0           2.0
# 4         husband  white    male          0.0          0.0           3.0
#
#   native-country-code native-country  class
# 0                 USA  united-states      1
# 1                 USA  united-states      1
# 2                 USA  united-states      0
# 3                 USA  united-states      0
# 4                 USA  united-states      1

# %%
df.isnull().sum()
# Out:
# id                           0
# social-security-number      14
# house-number                27
# age-group                   13
# workclass                 1057
# fnlwgt                      23
# education                   20
# education-num               14
# marital-status              23
# occupation                1054
# relationship                21
# race                        22
# sex                         22
# capitalgain                 23
# capitalloss                 21
# hoursperweek                21
# native-country-code        399
# native-country             398
# class                        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3172

# %%
df.nunique()
# Out:
# id                        20900
# social-security-number    20885
# house-number               8719
# age-group                     5
# workclass                     8
# fnlwgt                    15042
# education                    16
# education-num                16
# marital-status                7
# occupation                   14
# relationship                  6
# race                          5
# sex                           2
# capitalgain                   5
# capitalloss                   5
# hoursperweek                  5
# native-country-code          40
# native-country               41
# class                         2
# dtype: int64

# %%
df[df['house-number'].isnull()]
# Out:
#           id  social-security-number  house-number  age-group  \
# 233    26886             118671723.0           NaN        0.0
# 417     7286             104235482.0           NaN        2.0
# 425    11014             938225326.0           NaN        3.0
# 2730    7513             761679180.0           NaN        1.0
# 3460   14952             609831688.0           NaN        3.0
# 3482   25062             909798730.0           NaN        0.0
# 3941   15750             402344671.0           NaN        2.0
# 4111   26365             570186797.0           NaN        1.0
# 4244    5952             769529776.0           NaN        0.0
# 5161   18277             738208830.0           NaN        1.0
# 5932    8455             806914607.0           NaN        0.0
# 7733    1497             552150936.0           NaN        2.0
# 10335  18179             224840689.0           NaN        2.0
# 11373  13806             470312942.0           NaN        0.0
# 11413  20512             410747056.0           NaN        1.0
# 11734   3400             819433321.0           NaN        2.0
# 12180  22546             116342765.0           NaN        2.0
# 12440  13068             721371548.0           NaN        3.0
# 12899  27433             348990921.0           NaN        2.0
# 13409   8627             497175718.0           NaN        2.0
# 15260   4567             720126690.0           NaN        1.0
# 15458  17228             319958261.0           NaN        0.0
# 15962  11281             524009976.0           NaN        0.0
# 16091   8252             739220784.0           NaN        1.0
# 19261  22569             461664464.0           NaN        2.0
# 19700  14231             719763858.0           NaN        4.0
# 19926  21833             137185385.0           NaN        3.0
#
#               workclass    fnlwgt     education  education-num  \
# 233             private   25265.0       hs-grad            9.0
# 417           state-gov  152307.0     bachelors           13.0
# 425           state-gov  391585.0     bachelors           13.0
# 2730            private  186886.0       hs-grad            9.0
# 3460   self-emp-not-inc  275625.0     bachelors           13.0
# 3482            private   52242.0       hs-grad            9.0
# 3941            private  116379.0       masters           14.0
# 4111            private  239130.0   prof-school           15.0
# 4244            private   31350.0       hs-grad            9.0
# 5161            private  118901.0       hs-grad            9.0
# 5932            private  221661.0          10th            6.0
# 7733       self-emp-inc  170174.0       hs-grad            9.0
# 10335  self-emp-not-inc  160120.0     doctorate           16.0
# 11373               NaN  208874.0  some-college           10.0
# 11413         local-gov  104509.0       masters           14.0
# 11734      self-emp-inc  172826.0  some-college           10.0
# 12180           private  319052.0     bachelors           13.0
# 12440  self-emp-not-inc  117865.0       hs-grad            9.0
# 12899           private  231689.0       hs-grad            9.0
# 13409         local-gov  131167.0       masters           14.0
# 15260           private  341846.0       masters           14.0
# 15458           private  187879.0           9th            5.0
# 15962               NaN  113301.0          11th            7.0
# 16091           private  189407.0       hs-grad            9.0
# 19261           private  498785.0       hs-grad            9.0
# 19700           private  200922.0       7th-8th            4.0
# 19926               NaN   32385.0       hs-grad            9.0
#
#            marital-status         occupation    relationship  \
# 233         never-married       craft-repair       own-child
# 417    married-civ-spouse     prof-specialty         husband
# 425    married-civ-spouse    exec-managerial         husband
# 2730             divorced    exec-managerial       unmarried
# 3460             divorced      other-service       unmarried
# 3482   married-civ-spouse              sales            wife
# 3941   married-civ-spouse     prof-specialty         husband
# 4111        never-married     prof-specialty       own-child
# 4244        never-married  handlers-cleaners   not-in-family
# 5161            separated  machine-op-inspct   not-in-family
# 5932        never-married              sales   not-in-family
# 7733   married-civ-spouse    exec-managerial         husband
# 10335            divorced       adm-clerical  other-relative
# 11373       never-married                NaN       own-child
# 11413           separated     prof-specialty       unmarried
# 11734  married-civ-spouse              sales         husband
# 12180  married-civ-spouse  handlers-cleaners            wife
# 12440   married-af-spouse       craft-repair         husband
# 12899  married-civ-spouse       craft-repair         husband
# 13409       never-married     prof-specialty   not-in-family
# 15260       never-married     prof-specialty   not-in-family
# 15458       never-married      other-service   not-in-family
# 15962           separated                NaN   not-in-family
# 16091  married-civ-spouse              sales         husband
# 19261  married-civ-spouse  handlers-cleaners         husband
# 19700             widowed  machine-op-inspct   not-in-family
# 19926            divorced                NaN   not-in-family
#
#                      race     sex  capitalgain  capitalloss  hoursperweek  \
# 233                 white    male          0.0          0.0           2.0
# 417                 white    male          0.0          0.0           2.0
# 425                 white    male          4.0          0.0           2.0
# 2730                white  female          0.0          0.0           3.0
# 3460   asian-pac-islander  female          0.0          0.0           3.0
# 3482                white  female          0.0          0.0           2.0
# 3941   asian-pac-islander    male          0.0          0.0           3.0
# 4111                white    male          0.0          0.0           2.0
# 4244                white    male          0.0          0.0           3.0
# 5161                white  female          0.0          0.0           2.0
# 5932                white  female          0.0          0.0           1.0
# 7733                white    male          0.0          0.0           3.0
# 10335               other    male          0.0          0.0           2.0
# 11373               white    male          0.0          0.0           2.0
# 11413               white  female          0.0          0.0           2.0
# 11734               white    male          4.0          0.0           3.0
# 12180  asian-pac-islander  female          0.0          0.0           2.0
# 12440               white    male          0.0          0.0           4.0
# 12899               white    male          0.0          0.0           2.0
# 13409               white  female          0.0          0.0           2.0
# 15260               white  female          0.0          0.0           3.0
# 15458               white    male          0.0          0.0           3.0
# 15962               white  female          0.0          0.0           1.0
# 16091               white    male          0.0          0.0           3.0
# 19261               white    male          0.0          0.0           2.0
# 19700               white  female          0.0          0.0           2.0
# 19926               white  female          0.0          0.0           1.0
#
#       native-country-code native-country  class
# 233                   USA  united-states      0
# 417                   USA  united-states      0
# 425                   USA  united-states      1
# 2730                  USA  united-states      0
# 3460                  ZAF          south      1
# 3482                  USA  united-states      1
# 3941                  TWN         taiwan      1
# 4111                  USA  united-states      0
# 4244                  GBR        england      0
# 5161                  USA  united-states      0
# 5932                  MEX         mexico      0
# 7733                  USA  united-states      1
# 10335                 NaN            NaN      0
# 11373                 USA  united-states      0
# 11413                 USA  united-states      0
# 11734                 USA  united-states      1
# 12180                 PHL    philippines      0
# 12440                 USA  united-states      0
# 12899                 USA  united-states      1
# 13409                 USA  united-states      0
# 15260                 USA  united-states      0
# 15458                 USA  united-states      0
# 15962                 USA  united-states      0
# 16091                 USA  united-states      0
# 19261                 USA  united-states      0
# 19700                 USA  united-states      0
# 19926                 USA  united-states      0

# %%
# Fill missing values in the 'house-number' column
df['house-number'].fillna('Not Provided', inplace=True)

# Get rows where 'house-number' was originally null
house_number = df[df['house-number'].isnull()]

# Print the rows with null values in 'house-number' before filling
print(house_number)
# Out:
# Empty DataFrame
# Columns: [id, social-security-number, house-number, age-group, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capitalgain, capitalloss, hoursperweek, native-country-code, native-country, class]
# Index: []

# %%
df.isnull().sum()
# Out:
# id                           0
# social-security-number      14
# house-number                 0
# age-group                   13
# workclass                 1057
# fnlwgt                      23
# education                   20
# education-num               14
# marital-status              23
# occupation                1054
# relationship                21
# race                        22
# sex                         22
# capitalgain                 23
# capitalloss                 21
# hoursperweek                21
# native-country-code        399
# native-country             398
# class                        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3145

# %%
df[df['age-group'].isnull()]
# Out:
#           id  social-security-number house-number  age-group workclass  \
# 66      4556             501488718.0       6107.0        NaN   private
# 1992   24799             835575941.0       8565.0        NaN   private
# 2111   22812             610809825.0       3420.0        NaN   private
# 2865   22631             393441600.0       8156.0        NaN   private
# 3768    3344             741226855.0       4597.0        NaN   private
# 3926    9545             652980512.0       1541.0        NaN   private
# 7082    4718             844373818.0       7839.0        NaN   private
# 7925   24192             434791712.0       1468.0        NaN   private
# 8020    9675             960875712.0       3259.0        NaN   private
# 11611  23453             505955904.0       5241.0        NaN   private
# 13934  27744             752654687.0       9765.0        NaN   private
# 18206  26280             124270702.0       6845.0        NaN   private
# 20533  26103             319025292.0       8300.0        NaN       NaN
#
#          fnlwgt     education  education-num      marital-status  \
# 66     175674.0     bachelors           13.0  married-civ-spouse
# 1992   195892.0  some-college           10.0            divorced
# 2111   121521.0   prof-school           15.0  married-civ-spouse
# 2865   189759.0       masters           14.0  married-civ-spouse
# 3768   186539.0       hs-grad            9.0            divorced
# 3926   250818.0  some-college           10.0       never-married
# 7082   169748.0       hs-grad            9.0            divorced
# 7925   176810.0       hs-grad            9.0  married-civ-spouse
# 8020   151874.0       hs-grad            9.0  married-civ-spouse
# 11611  549174.0       hs-grad            9.0  married-civ-spouse
# 13934  202560.0    assoc-acdm           12.0           separated
# 18206  256813.0       masters           14.0  married-civ-spouse
# 20533  299197.0       hs-grad            9.0       never-married
#
#               occupation    relationship   race     sex  capitalgain  \
# 66                 sales         husband  white    male          0.0
# 1992    transport-moving   not-in-family  black  female          0.0
# 2111      prof-specialty         husband  white    male          4.0
# 2865               sales         husband  white    male          0.0
# 3768        craft-repair  other-relative  white    male          0.0
# 3926        adm-clerical   not-in-family  white    male          0.0
# 7082   handlers-cleaners   not-in-family  white    male          0.0
# 7925       other-service         husband  white    male          0.0
# 8020       other-service            wife  black  female          0.0
# 11611       craft-repair         husband  white    male          0.0
# 13934       adm-clerical       unmarried  white  female          0.0
# 18206     prof-specialty         husband  white    male          0.0
# 20533                NaN   not-in-family  white    male          0.0
#
#        capitalloss  hoursperweek native-country-code native-country  class
# 66             0.0           3.0                 USA  united-states      1
# 1992           0.0           2.0                 USA  united-states      0
# 2111           0.0           NaN                 USA  united-states      1
# 2865           0.0           2.0                 USA  united-states      1
# 3768           0.0           3.0                 USA  united-states      1
# 3926           0.0           2.0                 USA  united-states      0
# 7082           0.0           2.0                 USA  united-states      0
# 7925           0.0           2.0                 USA  united-states      0
# 8020           0.0           3.0                 USA  united-states      0
# 11611          0.0           3.0                 USA  united-states      1
# 13934          0.0           2.0                 USA  united-states      1
# 18206          3.0           2.0                 USA  united-states      1
# 20533          0.0           1.0                 USA  united-states      0

# %%
# Fill missing values in the 'house-number' column
df['age-group'].fillna('Not Provided', inplace=True)

# Get rows where 'house-number' was originally null
age_group = df[df['age-group'].isnull()]

# Print the rows with null values in 'house-number' before filling
print(age_group)
# Out:
# Empty DataFrame
# Columns: [id, social-security-number, house-number, age-group, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capitalgain, capitalloss, hoursperweek, native-country-code, native-country, class]
# Index: []

# %%
df_age_group = df.query("`age-group` == 'Not Provided'")
df_age_group.head()
# Out:
#          id  social-security-number house-number     age-group workclass  \
# 66     4556             501488718.0       6107.0  Not Provided   private
# 1992  24799             835575941.0       8565.0  Not Provided   private
# 2111  22812             610809825.0       3420.0  Not Provided   private
# 2865  22631             393441600.0       8156.0  Not Provided   private
# 3768   3344             741226855.0       4597.0  Not Provided   private
#
#         fnlwgt     education  education-num      marital-status  \
# 66    175674.0     bachelors           13.0  married-civ-spouse
# 1992  195892.0  some-college           10.0            divorced
# 2111  121521.0   prof-school           15.0  married-civ-spouse
# 2865  189759.0       masters           14.0  married-civ-spouse
# 3768  186539.0       hs-grad            9.0            divorced
#
#             occupation    relationship   race     sex  capitalgain  \
# 66               sales         husband  white    male          0.0
# 1992  transport-moving   not-in-family  black  female          0.0
# 2111    prof-specialty         husband  white    male          4.0
# 2865             sales         husband  white    male          0.0
# 3768      craft-repair  other-relative  white    male          0.0
#
#       capitalloss  hoursperweek native-country-code native-country  class
# 66            0.0           3.0                 USA  united-states      1
# 1992          0.0           2.0                 USA  united-states      0
# 2111          0.0           NaN                 USA  united-states      1
# 2865          0.0           2.0                 USA  united-states      1
# 3768          0.0           3.0                 USA  united-states      1

# %%
df.isnull().sum().sum()
# Out:
# 3132

# %%
df.isnull().sum()
# Out:
# id                           0
# social-security-number      14
# house-number                 0
# age-group                    0
# workclass                 1057
# fnlwgt                      23
# education                   20
# education-num               14
# marital-status              23
# occupation                1054
# relationship                21
# race                        22
# sex                         22
# capitalgain                 23
# capitalloss                 21
# hoursperweek                21
# native-country-code        399
# native-country             398
# class                        0
# dtype: int64

# %%
df['workclass'].fillna('Not Provided', inplace=True)

work_class = df[df['workclass'].isnull()]

work_class
# Out:
# Empty DataFrame
# Columns: [id, social-security-number, house-number, age-group, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capitalgain, capitalloss, hoursperweek, native-country-code, native-country, class]
# Index: []

# %%
df_work_class = df.query("`workclass` == 'Not Provided'")
df_work_class.head()
# Out:
#         id  social-security-number house-number age-group     workclass  \
# 17    9334             471717424.0       8171.0       0.0  Not Provided
# 25   20004             497898076.0       7948.0       4.0  Not Provided
# 54    1334             764326795.0       7562.0       4.0  Not Provided
# 91   19684             477813678.0        917.0       1.0  Not Provided
# 106  21828             634313602.0       1977.0       0.0  Not Provided
#
#        fnlwgt     education  education-num      marital-status occupation  \
# 17   180339.0  some-college           10.0       never-married        NaN
# 25   247986.0   prof-school           15.0  married-civ-spouse        NaN
# 54   365996.0       hs-grad            9.0             widowed        NaN
# 91   565769.0     preschool            1.0       never-married        NaN
# 106   94746.0  some-college           10.0       never-married        NaN
#
#       relationship   race     sex  capitalgain  capitalloss  hoursperweek  \
# 17       own-child  white  female          0.0          0.0           1.0
# 25         husband  white    male          0.0          0.0           1.0
# 54       unmarried  white  female          2.0          0.0           2.0
# 91   not-in-family  black    male          0.0          0.0           2.0
# 106      own-child  white    male          0.0          0.0           2.0
#
#     native-country-code native-country  class
# 17                  USA  united-states      0
# 25                  USA  united-states      1
# 54                  USA  united-states      1
# 91                  ZAF          south      0
# 106                 PRT       portugal      0

# %%
df.isnull().sum()
# Out:
# id                           0
# social-security-number      14
# house-number                 0
# age-group                    0
# workclass                    0
# fnlwgt                      23
# education                   20
# education-num               14
# marital-status              23
# occupation                1054
# relationship                21
# race                        22
# sex                         22
# capitalgain                 23
# capitalloss                 21
# hoursperweek                21
# native-country-code        399
# native-country             398
# class                        0
# dtype: int64

# %%
occupation_null = df[df['occupation'].isnull()]
occupation_null
# Out:
#           id  social-security-number house-number age-group     workclass  \
# 17      9334             471717424.0       8171.0       0.0  Not Provided
# 25     20004             497898076.0       7948.0       4.0  Not Provided
# 54      1334             764326795.0       7562.0       4.0  Not Provided
# 91     19684             477813678.0        917.0       1.0  Not Provided
# 106    21828             634313602.0       1977.0       0.0  Not Provided
# ...      ...                     ...          ...       ...           ...
# 20774  22002             262580857.0       3477.0       4.0  Not Provided
# 20832  26054             997325140.0        484.0       0.0  Not Provided
# 20852   3556             915712825.0       2011.0       4.0  Not Provided
# 20857   1899             589790742.0       6113.0       4.0  Not Provided
# 20890  16850             866938421.0       4673.0       3.0  Not Provided
#
#          fnlwgt     education  education-num      marital-status occupation  \
# 17     180339.0  some-college           10.0       never-married        NaN
# 25     247986.0   prof-school           15.0  married-civ-spouse        NaN
# 54     365996.0       hs-grad            9.0             widowed        NaN
# 91     565769.0     preschool            1.0       never-married        NaN
# 106     94746.0  some-college           10.0       never-married        NaN
# ...         ...           ...            ...                 ...        ...
# 20774   76641.0       masters           14.0  married-civ-spouse        NaN
# 20832  239120.0     bachelors           13.0       never-married        NaN
# 20852  113445.0       5th-6th            3.0  married-civ-spouse        NaN
# 20857  147653.0  some-college           10.0  married-civ-spouse        NaN
# 20890   61985.0           9th            5.0           separated        NaN
#
#         relationship                race     sex  capitalgain  capitalloss  \
# 17         own-child               white  female          0.0          0.0
# 25           husband               white    male          0.0          0.0
# 54         unmarried               white  female          2.0          0.0
# 91     not-in-family               black    male          0.0          0.0
# 106        own-child               white    male          0.0          0.0
# ...              ...                 ...     ...          ...          ...
# 20774        husband               white    male          4.0          0.0
# 20832  not-in-family               white    male          0.0          0.0
# 20852        husband               white    male          0.0          0.0
# 20857           wife               white  female          0.0          0.0
# 20890  not-in-family  amer-indian-eskimo  female          0.0          0.0
#
#        hoursperweek native-country-code native-country  class
# 17              1.0                 USA  united-states      0
# 25              1.0                 USA  united-states      1
# 54              2.0                 USA  united-states      1
# 91              2.0                 ZAF          south      0
# 106             2.0                 PRT       portugal      0
# ...             ...                 ...            ...    ...
# 20774           2.0                 POL         poland      1
# 20832           0.0                 USA  united-states      0
# 20852           0.0                 USA  united-states      0
# 20857           2.0                 USA  united-states      0
# 20890           0.0                 USA  united-states      0
#
# [1054 rows x 19 columns]

# %%
df['occupation'].unique()
# Out:
# array(['exec-managerial', 'prof-specialty', 'other-service',
#        'machine-op-inspct', 'sales', 'handlers-cleaners', 'craft-repair',
#        'adm-clerical', 'tech-support', nan, 'farming-fishing',
#        'transport-moving', 'priv-house-serv', 'protective-serv',
#        'armed-forces'], dtype=object)

# %%
df['occupation'].fillna('Not Provided', inplace=True)
occupation_null = df[df['occupation'].isnull()]
occupation_null
# Out:
# Empty DataFrame
# Columns: [id, social-security-number, house-number, age-group, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capitalgain, capitalloss, hoursperweek, native-country-code, native-country, class]
# Index: []

# %%
df_occupation_null = df.query("`workclass` == 'Not Provided'")
df_occupation_null.head()
# Out:
#         id  social-security-number house-number age-group     workclass  \
# 17    9334             471717424.0       8171.0       0.0  Not Provided
# 25   20004             497898076.0       7948.0       4.0  Not Provided
# 54    1334             764326795.0       7562.0       4.0  Not Provided
# 91   19684             477813678.0        917.0       1.0  Not Provided
# 106  21828             634313602.0       1977.0       0.0  Not Provided
#
#        fnlwgt     education  education-num      marital-status    occupation  \
# 17   180339.0  some-college           10.0       never-married  Not Provided
# 25   247986.0   prof-school           15.0  married-civ-spouse  Not Provided
# 54   365996.0       hs-grad            9.0             widowed  Not Provided
# 91   565769.0     preschool            1.0       never-married  Not Provided
# 106   94746.0  some-college           10.0       never-married  Not Provided
#
#       relationship   race     sex  capitalgain  capitalloss  hoursperweek  \
# 17       own-child  white  female          0.0          0.0           1.0
# 25         husband  white    male          0.0          0.0           1.0
# 54       unmarried  white  female          2.0          0.0           2.0
# 91   not-in-family  black    male          0.0          0.0           2.0
# 106      own-child  white    male          0.0          0.0           2.0
#
#     native-country-code native-country  class
# 17                  USA  united-states      0
# 25                  USA  united-states      1
# 54                  USA  united-states      1
# 91                  ZAF          south      0
# 106                 PRT       portugal      0

# %%
df.isnull().sum()
# Out:
# id                          0
# social-security-number     14
# house-number                0
# age-group                   0
# workclass                   0
# fnlwgt                     23
# education                  20
# education-num              14
# marital-status             23
# occupation                  0
# relationship               21
# race                       22
# sex                        22
# capitalgain                23
# capitalloss                21
# hoursperweek               21
# native-country-code       399
# native-country            398
# class                       0
# dtype: int64

# %%
df['fnlwgt'].fillna(df['fnlwgt'].mean(), inplace=True)
fnlwgt_null = df[df['fnlwgt'].isnull()]
fnlwgt_null
# Out:
# Empty DataFrame
# Columns: [id, social-security-number, house-number, age-group, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capitalgain, capitalloss, hoursperweek, native-country-code, native-country, class]
# Index: []

# %%
df.isnull().sum()
# Out:
# id                          0
# social-security-number     14
# house-number                0
# age-group                   0
# workclass                   0
# fnlwgt                      0
# education                  20
# education-num              14
# marital-status             23
# occupation                  0
# relationship               21
# race                       22
# sex                        22
# capitalgain                23
# capitalloss                21
# hoursperweek               21
# native-country-code       399
# native-country            398
# class                       0
# dtype: int64

# %%
df.head()
# Out:
#       id  social-security-number house-number age-group     workclass  \
# 0   8616             830617145.0       8732.0       2.0  self-emp-inc
# 1  21982             151595184.0       1894.0       3.0     local-gov
# 2  11191             303184281.0       9466.0       0.0       private
# 3  22229             369287837.0       8511.0       2.0       private
# 4  20732             420084973.0       1281.0       3.0       private
#
#      fnlwgt  education  education-num      marital-status         occupation  \
# 0  270079.0  bachelors           13.0  married-civ-spouse    exec-managerial
# 1  146325.0  doctorate           16.0  married-civ-spouse     prof-specialty
# 2  240767.0    hs-grad            9.0       never-married      other-service
# 3  118536.0    hs-grad            9.0            divorced  machine-op-inspct
# 4  160440.0  bachelors           13.0  married-civ-spouse              sales
#
#      relationship   race     sex  capitalgain  capitalloss  hoursperweek  \
# 0         husband  white    male          0.0          0.0           3.0
# 1         husband  white    male          0.0          2.0           2.0
# 2   not-in-family  white  female          0.0          0.0           1.0
# 3  other-relative  black    male          0.0          0.0           2.0
# 4         husband  white    male          0.0          0.0           3.0
#
#   native-country-code native-country  class
# 0                 USA  united-states      1
# 1                 USA  united-states      1
# 2                 USA  united-states      0
# 3                 USA  united-states      0
# 4                 USA  united-states      1

# %%
df['education'].unique()
# Out:
# array(['bachelors', 'doctorate', 'hs-grad', '10th', 'some-college',
#        'masters', 'prof-school', '5th-6th', '7th-8th', 'assoc-acdm',
#        '12th', 'preschool', 'assoc-voc', '9th', '11th', '1st-4th', nan],
#       dtype=object)

# %%
df['capitalloss']
# Out:
# 0        0.0
# 1        2.0
# 2        0.0
# 3        0.0
# 4        0.0
#         ...
# 20895    0.0
# 20896    0.0
# 20897    0.0
# 20898    0.0
# 20899    0.0
# Name: capitalloss, Length: 20900, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# Create an instance of LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'sex' column
df['sex'] = label_encoder.fit_transform(df['sex'])

# %%
df.head()
# Out:
#       id  social-security-number house-number age-group     workclass  \
# 0   8616             830617145.0       8732.0       2.0  self-emp-inc
# 1  21982             151595184.0       1894.0       3.0     local-gov
# 2  11191             303184281.0       9466.0       0.0       private
# 3  22229             369287837.0       8511.0       2.0       private
# 4  20732             420084973.0       1281.0       3.0       private
#
#      fnlwgt  education  education-num      marital-status         occupation  \
# 0  270079.0  bachelors           13.0  married-civ-spouse    exec-managerial
# 1  146325.0  doctorate           16.0  married-civ-spouse     prof-specialty
# 2  240767.0    hs-grad            9.0       never-married      other-service
# 3  118536.0    hs-grad            9.0            divorced  machine-op-inspct
# 4  160440.0  bachelors           13.0  married-civ-spouse              sales
#
#      relationship   race  sex  capitalgain  capitalloss  hoursperweek  \
# 0         husband  white    1          0.0          0.0           3.0
# 1         husband  white    1          0.0          2.0           2.0
# 2   not-in-family  white    0          0.0          0.0           1.0
# 3  other-relative  black    1          0.0          0.0           2.0
# 4         husband  white    1          0.0          0.0           3.0
#
#   native-country-code native-country  class
# 0                 USA  united-states      1
# 1                 USA  united-states      1
# 2                 USA  united-states      0
# 3                 USA  united-states      0
# 4                 USA  united-states      1
